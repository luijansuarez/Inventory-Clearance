# %% [markdown]
# <a href="https://colab.research.google.com/github/luijansuarez/Inventory-Clearance/blob/main/InventoryClearance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://www.savilaeducation.com/" target="_blank">
#   <img src="https://res.cloudinary.com/dnq7vo3xt/image/upload/v1752564274/banner_google_collab_white_m4paih.png"
#        alt="Company Banner" width="100%">
# </a>

# %% [markdown]
# # Libraries

# %%
'Importamos las librerías que vamos a utilizar'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data
#
# Import sku data

# %%
'Leer la data de excel'
df = pd.read_excel('sku_data.xlsx')

# %%
'Conocer la "aparencia" del df'
df.head()
# Out:
#          sku  inventory  sales_per_month  price  clearance_price  holding_cost
# 0  L-FW-8504        873               42   8.93             1.83          0.84
# 1  N-KI-3619        533               39   7.86             0.50          0.47
# 2  C-TS-9945        347                4   2.22             0.44          0.05
# 3  N-QB-3444        848               14  10.85             1.14          0.20
# 4  W-IF-7282        585               21   6.23             1.05          0.36

# %%
'Revisamos cuáles son los tipos de los valores cada columna'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sku              20000 non-null  object
#  1   inventory        20000 non-null  int64
#  2   sales_per_month  20000 non-null  int64
#  3   price            20000 non-null  float64
#  4   clearance_price  20000 non-null  float64
#  5   holding_cost     20000 non-null  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 937.6+ KB

# %% [markdown]
# # Estimate revenue until zero inventory (without discount)

# %%
'Determinamos cuál será el rango superior de los ingresos generados con el inventario existente'
df['max_revenue_without_discount'] = df.price * df.inventory

# %%
print (F'Max revenue at full price without discount {df['max_revenue_without_discount'].sum():,.2f}')
# Out:
# Max revenue at full price without discount 60,355,233.17

# %%
'Determinamos cuál será el rango inferior de los ingresos generados con el inventario existente'
df['max_revenue_clearance_without_discount'] = df.clearance_price * df.inventory

# %%
print (F'Max revenue at clearance price without discount {df['max_revenue_clearance_without_discount'].sum():,.2f}')
# Out:
# Max revenue at clearance price without discount 6,127,106.89

# %%
'Debido a que es una operación que se debe realizar con cada SKU, creamos una función que corra con todas las variables disponibles'
def calculate_holding_cost_until_zero(row):

  inventory = row['inventory']
  sales = row['sales_per_month']
  holding_cost = row['holding_cost']

  current_inventory = inventory
  total_cost = 0
  while current_inventory > 0:
      total_cost += current_inventory * holding_cost
      current_inventory -= sales
  return total_cost

# %%
'Aplicamos la función anterior al df para crear una nueva columna que contenga los costos de almacenamiento hasta que el inventario llegue a cero'
df['holding_cost_until_zero'] = df.apply(calculate_holding_cost_until_zero, axis=1)

# %%
'Sumamos los costos de almacenamiento de cada SKU'
print (F'Holding cost until zero {df['holding_cost_until_zero'].sum():,.2f}')
# Out:
# Holding cost until zero 99,790,894.96

# %%
'Determinamos la rentabilidad utilizando el rango superior de ingresos menos los costos de almacenamiento'
df['profit_without_discount'] = df['max_revenue_without_discount'] - df['holding_cost_until_zero']

# %%
print (F'Profit without discount {df['profit_without_discount'].sum():,.2f}')
# Out:
# Profit without discount -39,435,661.79

# %%
'Identificamos el % de SKUs que están generando pérdidas para el negocio'
print(F'% of SKUs that are generating losses {(df['profit_without_discount'] < 0).mean():.2%}')
# Out:
# % of SKUs that are generating losses 28.02%

# %%
'Calculamos la rentabilidad si no quisieramos aplicar descuentos si no utilizar el precio de liquidación para aquellos SKUs que están generando perdidas'
profit_profitable = df[df['profit_without_discount']>= 0]['profit_without_discount'].sum()
profit_loss = df[df['profit_without_discount']< 0]['max_revenue_clearance_without_discount'].sum()

print (f'Profit from smart clearance { profit_profitable + profit_loss:,.0f}')
# Out:
# Profit from smart clearance 21,787,454

# %% [markdown]
# # Estimate revenue until zero but taking into account the discount value of money

# %%
'Generamos una función, muy similar a la anterior, que determinará el costo de almacenamiento tomando en cuenta el valor presente del dinero'
def calculate_cost_until_zero_with_discount(row, annual_rate = 0.05):

    interest_rate = annual_rate/12

    inventory = row['inventory']
    sales = row['sales_per_month']
    holding_cost = row['holding_cost']

    current_inventory = inventory
    total_cost = 0
    t = 0
    while current_inventory > 0:
        total_cost += current_inventory * (holding_cost / ((1+interest_rate)** t))
        current_inventory -= sales
        t += 1
    return total_cost

# %%
'Generamos una función que determinará los ingresos tomando en cuenta el valor presente del dinero'
def calculate_revenue_until_zero_with_discount(row, annual_rate = 0.05):

    interest_rate = annual_rate/12

    inventory = row['inventory']
    sales = row['sales_per_month']
    price = row['price']

    current_inventory = inventory
    total_revenue = 0
    t = 0
    while current_inventory > 0:
        total_revenue += sales * (price / ((1 +interest_rate)**t))
        current_inventory -= sales
        t += 1
    return total_revenue

# %%
'Calculamos los costos aplicando la tasa de intereses proporcionada para el caso'
df['cost_with_discount'] = df.apply(
    calculate_cost_until_zero_with_discount,
    axis=1,
    annual_rate = 0.04
    )

# %%
'Calculamos los costos aplicando la tasa de intereses proporcionada para el caso'
df['revenue_with_discount'] = df.apply(
    calculate_revenue_until_zero_with_discount,
    axis=1,
    annual_rate = 0.04
    )

# %%
'Calculamos la rentabilidad tomando en cuenta el Valor Presente del dinero'
df['discount_profit'] = df['revenue_with_discount'] - df['cost_with_discount']

# %%
print(df['cost_with_discount'].sum())
# Out:
# 80245761.29147047

# %%
print(df['revenue_with_discount'].sum())
# Out:
# 57012610.41238192

# %%
print (F'Profit until zero with discount (4%) {df['discount_profit'].sum():,.0f} $')
# Out:
# Profit until zero with discount (4%) -23,233,151 $

# %%
'Calculamos la rentabilidad, tomando en cuenta el Valor Presente del dinero, si no quisieramos aplicar descuentos si no utilizar el precio de liquidación para aquellos SKUs que están generando perdidas'
profit_profitable = df[df['discount_profit']>= 0]['discount_profit'].sum()
profit_loss = df[df['discount_profit']< 0]['max_revenue_clearance_without_discount'].sum()

print (f'Profit from smart clearance { profit_profitable + profit_loss:,.0f}')
# Out:
# Profit from smart clearance 22,172,667

# %% [markdown]
# # Determine Discounts
#
# Determine the optimal discount value for each sku, based on marketing fndings

# %%
'Creamos un nuevo Data Frame con la información de market_research'
discount_data = pd.read_excel('market_research.xlsx')

# %%
discount_data.head()
# Out:
#   product    10    20    30    50    70
# 0       A  0.00  0.27  0.39  0.71  0.71
# 1       B  0.45  0.49  0.54  0.54  0.61
# 2       C  0.04  0.05  0.25  0.25  0.41
# 3       D  0.03  0.16  0.24  0.26  0.27
# 4       E  0.32  0.34  0.53  0.59  0.95

# %%
'Verificamos si existen valores nulos'
discount_data.isna().sum()
# Out:
# product    0
# 10         0
# 20         0
# 30         0
# 50         0
# 70         0
# dtype: int64

# %%
'Revisamos el formato de los valores en este dataframe'
discount_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   product  26 non-null     object
#  1   10       26 non-null     float64
#  2   20       26 non-null     float64
#  3   30       26 non-null     float64
#  4   50       26 non-null     float64
#  5   70       26 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.3+ KB

# %%
'Vamos a generar un nuevo dataframe independiente cuyos valores sean aquellos SKUs que generan perdidas monetarias después de aplicar el valor presente del dinero'
lossing_product = df[df['discount_profit'] < 0].iloc[:,:6].reset_index(drop=True).copy()

# %%
lossing_product
# Out:
#             sku  inventory  sales_per_month  price  clearance_price  \
# 0     L-FW-8504        873               42   8.93             1.83
# 1     C-TS-9945        347                4   2.22             0.44
# 2     W-CN-7224        654                8   4.93             0.98
# 3     J-IU-6818        742               22   6.51             0.53
# 4     X-JV-9924        918               20   7.77            -0.19
# ...         ...        ...              ...    ...              ...
# 5605  O-FW-7476        691               21   2.07             0.40
# 5606  J-ZD-1041        117                2   5.95             0.13
# 5607  H-AM-9158        712                7   3.36             0.06
# 5608  B-JM-4516        413                7   7.77             1.10
# 5609  Q-XK-2066        924               25   5.48             0.49
#
#       holding_cost
# 0             0.84
# 1             0.05
# 2             0.30
# 3             0.47
# 4             0.46
# ...            ...
# 5605          0.18
# 5606          0.48
# 5607          0.20
# 5608          0.39
# 5609          0.44
#
# [5610 rows x 6 columns]

# %%
'Creamos una función que determine la rentabilidad tomando en cuenta el valor presente del dinero. A diferencia de anteriormente, en esta función se calcula los ingresos y costos en la misma función.'
def profit_discount (inventory, sales_per_month, price, holding_cost, annual_rate = 0.05):

    interest_rate = annual_rate/12

    current_inventory = inventory
    total_profit = 0
    t = 0
    while current_inventory > 0:
      sold = min(current_inventory, sales_per_month)
      revenue = sold * (price / ((1 +interest_rate)**t))
      costs = current_inventory * (holding_cost / ((1+interest_rate)** t))
      total_profit += (revenue - costs)
      current_inventory -= sold
      t += 1
    return total_profit

# %%
'Vamos a crear un Dictionary en el cual se tomará aquellos SKUs que están generando perdidas y se determinará si se deben vender con precio de liquidación o con un descuento. Es importante mencionar que no se está buscando una rentabilidad positiva para todos los SKUs, simplemente generar la menor perdida posible.'
decision_losing_products = dict()

price_discount = list(discount_data.columns[1:])

for idx, row in lossing_product.iterrows():

    sku,	inventory,	sales_per_month,	price,	clearance_price,	holding_cost = row
    product_category = sku.split('-')[0]
    lift = discount_data[discount_data['product'] == product_category].values[0][1:]

    clearance_revenue = inventory * clearance_price
    decision = 'clearance'
    best_profit = clearance_revenue

    for s, p in zip(lift, price_discount):
      lift_sales = sales_per_month * (1+s)
      price_disc = price * (1-(p/100))
      profit = profit_discount(inventory, lift_sales, price_disc, holding_cost, 0.04)
      if profit > best_profit:
        decision = f'{p}% discount'
        best_profit = profit
    decision_losing_products[sku] = (decision, best_profit)

# %%
decision_losing_products
# Out:
# {'L-FW-8504': ('clearance', 1597.5900000000001),
#  'C-TS-9945': ('clearance', 152.68),
#  'W-CN-7224': ('clearance', 640.92),
#  'J-IU-6818': ('clearance', 393.26000000000005),
#  'X-JV-9924': ('clearance', -174.42000000000002),
#  'G-YO-8975': ('clearance', 521.09),
#  'R-BB-9827': ('clearance', 1059.03),
#  'Q-IU-9754': ('clearance', 322.83),
#  'V-LA-8293': ('clearance', 74.5),
#  'H-PE-6622': ('clearance', -31.450000000000003),
#  'E-UB-4506': ('clearance', 367.12),
#  'T-BT-2743': ('clearance', -74.72),
#  'N-VF-5257': ('clearance', 68.60000000000001),
#  'N-TZ-5915': ('clearance', 136.79999999999998),
#  'M-DX-6158': ('clearance', -87.21000000000001),
#  'K-MW-8242': ('clearance', 66.0),
#  'Q-GF-2144': ('clearance', 1435.0),
#  'C-XV-3734': ('clearance', 1228.77),
#  'N-EM-2078': ('clearance', 1192.98),
#  'I-AV-7179': ('clearance', 102.89999999999999),
#  'R-VY-3828': ('clearance', 858.52),
#  'P-QC-2709': ('clearance', 204.24),
#  'H-UV-6930': ('10% discount', 402.53576069686864),
#  'I-QW-4940': ('clearance', 765.06),
#  'I-CO-6838': ('clearance', 652.38),
#  'A-EV-3574': ('clearance', 570.24),
#  'P-KQ-6708': ('clearance', 138.4),
#  'E-YA-1875': ('clearance', 346.5),
#  'W-GK-7970': ('clearance', 48.239999999999995),
#  'Y-RX-3137': ('clearance', 1033.5600000000002),
#  'W-TZ-5304': ('clearance', -35.36),
#  'H-PT-1397': ('clearance', 387.66),
#  'J-BP-1711': ('clearance', 113.77),
#  'P-TQ-5087': ('clearance', -65.03),
#  'W-XC-4642': ('clearance', 102.75),
#  'Z-JS-8627': ('clearance', 451.78),
#  'C-ZK-3809': ('clearance', 0.0),
#  'O-WI-9425': ('clearance', -161.5),
#  'E-XT-9361': ('clearance', -7.92),
#  'X-VM-5933': ('clearance', 1157.1),
#  'C-ZK-6518': ('clearance', 905.0),
#  'I-PV-8334': ('clearance', 219.12),
#  'G-FX-4079': ('clearance', 354.65),
#  'L-MQ-5800': ('clearance', 161.46),
#  'I-UQ-9573': ('clearance', 349.2),
#  'N-UT-3406': ('clearance', -159.22),
#  'B-DK-9190': ('clearance', 165.0),
#  'A-OX-2574': ('clearance', 56.980000000000004),
#  'V-PQ-2903': ('clearance', 199.51999999999998),
#  'B-IM-3965': ('clearance', 1173.02),
#  'V-WX-5176': ('30% discount', 18.18186170333629),
#  'F-DK-5641': ('clearance', -6.68),
#  'B-NF-8975': ('clearance', 1218.3600000000001),
#  'E-CV-6539': ('clearance', 1991.04),
#  'U-VA-9744': ('clearance', 883.5),
#  'R-XM-8557': ('clearance', 164.01000000000002),
#  'Q-UE-6341': ('clearance', 735.0),
#  'K-GR-2930': ('clearance', 666.6500000000001),
#  'Q-VG-9391': ('clearance', 447.32000000000005),
#  'U-ZO-5355': ('clearance', 479.05),
#  'J-WI-7253': ('clearance', 227.04),
#  'P-QU-7000': ('clearance', 372.24),
#  'W-TB-5098': ('clearance', 1251.84),
#  'U-AC-6459': ('clearance', 525.0),
#  'J-DU-1180': ('clearance', 178.8),
#  'R-DN-7099': ('clearance', -33.12),
#  'P-BA-7945': ('clearance', -29.05),
#  'U-DL-3081': ('clearance', 236.32000000000002),
#  'O-UA-7972': ('clearance', 255.0),
#  'Z-PK-3693': ('clearance', 180.44),
#  'D-DD-6776': ('clearance', 216.72),
#  'D-VK-1297': ('clearance', 35.4),
#  'R-PK-6465': ('clearance', 16.83),
#  'V-LU-6020': ('clearance', 34.04),
#  'E-YA-1090': ('clearance', 214.83),
#  'I-RS-9767': ('clearance', 248.88),
#  'H-LT-7765': ('clearance', 675.8399999999999),
#  'N-PC-5947': ('clearance', 1123.2199999999998),
#  'G-CH-5165': ('clearance', 625.51),
#  'D-HA-6012': ('clearance', 730.55),
#  'N-IU-6710': ('clearance', -35.4),
#  'Z-CD-1180': ('clearance', 24.66),
#  'L-WN-7124': ('clearance', 241.08),
#  'A-SH-5397': ('clearance', 543.6),
#  'F-JR-6094': ('clearance', 724.47),
#  'U-OQ-6069': ('clearance', 534.06),
#  'D-AT-7591': ('clearance', -206.8),
#  'X-XQ-9624': ('clearance', 669.7600000000001),
#  'B-TT-9723': ('clearance', 1257.9499999999998),
#  'J-HY-1614': ('clearance', 46.08),
#  'K-OM-9842': ('clearance', 870.7500000000001),
#  'U-LZ-3146': ('clearance', 1303.1200000000001),
#  'N-JA-7396': ('clearance', 238.8),
#  'C-HV-9917': ('clearance', 86.71),
#  'B-PE-8955': ('clearance', 732.0),
#  'O-AJ-4462': ('clearance', 1489.93),
#  'J-RV-9157': ('clearance', 746.64),
#  'O-VJ-7055': ('clearance', 838.9499999999999),
#  'E-KF-8595': ('clearance', 234.48),
#  'O-FJ-9183': ('clearance', 248.0),
#  'H-SS-3620': ('clearance', 703.92),
#  'Z-DR-9281': ('clearance', 1834.47),
#  'D-OW-5234': ('clearance', 22.35),
#  'I-SI-8325': ('clearance', 673.2),
#  'L-PU-3349': ('clearance', 284.7),
#  'H-HF-1205': ('clearance', 1219.4),
#  'S-KQ-3602': ('clearance', 1707.96),
#  'X-RK-6239': ('clearance', 282.0),
#  'O-SB-5431': ('clearance', 753.9399999999999),
#  'R-KD-7984': ('clearance', 911.88),
#  'S-OL-1075': ('10% discount', 25.314697128290796),
#  'P-UM-9526': ('clearance', 907.48),
#  'S-BF-1901': ('clearance', 1248.36),
#  'L-FR-1050': ('clearance', 483.84000000000003),
#  'E-LI-3744': ('clearance', 271.44),
#  'X-ET-5027': ('clearance', 4.97),
#  'I-ZX-3730': ('clearance', 1270.4),
#  'C-RB-6240': ('clearance', 250.63),
#  'F-GZ-1502': ('clearance', 53.9),
#  'A-LU-5304': ('clearance', 1188.6),
#  'J-MI-1968': ('clearance', 330.2),
#  'I-TB-1242': ('clearance', 687.1800000000001),
#  'B-FZ-7673': ('clearance', 157.08),
#  'S-SB-7324': ('clearance', 329.22),
#  'E-DZ-1994': ('clearance', -148.35),
#  'N-MA-6268': ('clearance', 380.54),
#  'K-OG-5039': ('clearance', 681.12),
#  'R-NK-2201': ('clearance', 463.32),
#  'L-NT-2941': ('clearance', 519.96),
#  'D-UD-6715': ('clearance', -45.12),
#  'A-KK-2236': ('clearance', 1290.42),
#  'R-XH-3638': ('clearance', 678.9399999999999),
#  'K-NY-4427': ('clearance', -192.5),
#  'W-ZC-6830': ('clearance', 1342.1200000000001),
#  'V-PI-5532': ('clearance', 261.24),
#  'D-AG-5339': ('clearance', 744.12),
#  'J-DW-4090': ('clearance', 280.44),
#  'U-OL-9881': ('clearance', 353.70000000000005),
#  'A-RP-6371': ('clearance', 608.4),
#  'V-SK-3602': ('clearance', 617.5),
#  'U-ZU-1493': ('clearance', 32.7),
#  'M-BC-8301': ('clearance', 113.39999999999999),
#  'I-QM-8285': ('10% discount', 220.75460843007522),
#  'F-MC-8136': ('clearance', 323.17999999999995),
#  'G-IF-7789': ('clearance', -54.96),
#  'O-HB-4884': ('clearance', 30.6),
#  'F-UP-4376': ('clearance', 405.48),
#  'Q-OG-8528': ('clearance', 950.8800000000001),
#  'D-DI-3159': ('clearance', 718.77),
#  'F-KO-4069': ('clearance', 1132.74),
#  'D-WO-6632': ('clearance', 808.92),
#  'C-LA-6353': ('clearance', 82.98),
#  'W-UL-5283': ('clearance', 1030.54),
#  'C-HY-4520': ('clearance', 1121.41),
#  'J-YT-2503': ('clearance', 221.04),
#  'U-MG-1433': ('clearance', 183.7),
#  'L-UT-6841': ('clearance', 174.69),
#  'C-LF-2875': ('clearance', -255.92000000000002),
#  'B-IL-7076': ('clearance', 504.43),
#  'U-BW-6693': ('clearance', 700.87),
#  'B-CZ-1204': ('10% discount', 92.26300730936782),
#  'A-JQ-8130': ('clearance', 753.6600000000001),
#  'S-EV-7370': ('clearance', 245.63),
#  'R-PB-8512': ('clearance', 673.0799999999999),
#  'Q-RB-6457': ('clearance', 41.160000000000004),
#  'M-HQ-5206': ('clearance', 45.290000000000006),
#  'A-ZV-9678': ('clearance', 223.56),
#  'E-SN-2253': ('clearance', 68.64),
#  'Q-TV-2318': ('clearance', -42.88),
#  'E-DJ-9297': ('clearance', 451.22),
#  'T-XX-5277': ('clearance', 304.26),
#  'R-DG-5439': ('clearance', 1642.2),
#  'R-AJ-2801': ('clearance', 314.57),
#  'N-PH-5460': ('clearance', 947.1600000000001),
#  'L-WD-6272': ('clearance', 37.96),
#  'G-BC-8824': ('clearance', 155.25),
#  'Y-WV-8091': ('clearance', 191.24),
#  'M-AJ-6614': ('clearance', 234.36),
#  'G-EC-5473': ('clearance', -69.84),
#  'M-HB-4969': ('clearance', -25.060000000000002),
#  'Q-ZL-9400': ('clearance', 171.0),
#  'Q-ZT-1336': ('clearance', 877.8000000000001),
#  'T-ZZ-5251': ('clearance', -86.83),
#  'T-EH-3923': ('clearance', 175.5),
#  'N-NL-4600': ('clearance', 21.45),
#  'V-HP-8086': ('clearance', -44.76),
#  'X-IA-7151': ('clearance', -372.4),
#  'T-ZH-5151': ('clearance', 0.0),
#  'U-AR-1998': ('clearance', 39.0),
#  'M-WU-5243': ('clearance', 134.4),
#  'A-QH-6888': ('clearance', 207.35999999999999),
#  'V-HP-7356': ('clearance', 217.89000000000001),
#  'O-NM-2636': ('clearance', 73.2),
#  'B-BV-7648': ('clearance', 93.61),
#  'X-WL-9341': ('clearance', 159.18),
#  'A-BA-6168': ('clearance', -47.650000000000006),
#  'E-FM-2323': ('clearance', 117.99000000000001),
#  'U-EZ-7389': ('clearance', 945.3),
#  'G-NZ-1087': ('clearance', 1582.56),
#  'A-GN-8271': ('clearance', 273.57),
#  'D-QE-4709': ('clearance', 212.8),
#  'V-IH-5220': ('30% discount', 314.9927690289165),
#  'T-TR-2584': ('clearance', 1166.88),
#  'D-HS-9431': ('clearance', 369.41),
#  'V-TY-8576': ('clearance', -108.32000000000001),
#  'H-UT-8636': ('clearance', 23.400000000000002),
#  'L-KD-1309': ('clearance', 472.50000000000006),
#  'B-BH-5543': ('clearance', 714.6),
#  'P-MR-1799': ('clearance', 209.56),
#  'L-AI-2520': ('clearance', 566.28),
#  'T-VN-8716': ('clearance', -158.4),
#  'K-BE-6826': ('clearance', 124.32),
#  'D-CD-3328': ('clearance', 451.95),
#  'X-FT-4031': ('clearance', 340.54999999999995),
#  'U-FP-6482': ('clearance', 198.88),
#  'S-EF-8463': ('clearance', -90.35000000000001),
#  'K-QB-8944': ('clearance', -82.72),
#  'O-HN-2584': ('clearance', 72.32000000000001),
#  'Q-RG-8751': ('clearance', 26.099999999999998),
#  'C-XG-5591': ('clearance', 693.72),
#  'J-FO-9997': ('clearance', 338.58),
#  'A-AZ-7997': ('clearance', 517.44),
#  'E-KB-4395': ('clearance', 292.12),
#  'U-YG-3427': ('clearance', 226.92),
#  'V-DJ-6400': ('clearance', 535.72),
#  'Y-NO-4669': ('clearance', 364.64),
#  'Z-MU-1428': ('clearance', 718.96),
#  'H-DN-2901': ('clearance', 128.04),
#  'A-RN-7192': ('clearance', 722.8000000000001),
#  'O-WJ-4052': ('clearance', 546.3399999999999),
#  'L-AC-3025': ('clearance', 86.4),
#  'Y-UY-2941': ('clearance', 320.79),
#  'F-QM-7347': ('clearance', 374.22),
#  'T-EW-3834': ('clearance', 236.92999999999998),
#  'R-NA-5493': ('clearance', 616.17),
#  'D-EJ-9101': ('clearance', 296.31),
#  'T-CW-6058': ('clearance', 604.4399999999999),
#  'C-CZ-4591': ('clearance', 127.67999999999999),
#  'I-DM-4940': ('clearance', 249.66),
#  'Q-UP-6502': ('clearance', 8.88),
#  'Y-RE-8817': ('clearance', 301.58000000000004),
#  'Z-KM-5621': ('clearance', 0.0),
#  'R-YP-9607': ('clearance', 208.98),
#  'Z-TO-5551': ('clearance', 668.1700000000001),
#  'W-WT-2311': ('clearance', -252.8),
#  'S-NO-8554': ('clearance', 1429.74),
#  'L-VQ-5716': ('clearance', -353.25),
#  'L-KT-5976': ('clearance', 313.5),
#  'S-NG-3843': ('clearance', -29.84),
#  'A-AI-1209': ('clearance', 792.54),
#  'H-ZF-7368': ('clearance', 100.42999999999999),
#  'J-MA-8717': ('clearance', 465.40000000000003),
#  'A-PQ-8646': ('clearance', 2251.38),
#  'R-TC-4892': ('clearance', 39.28),
#  'F-GK-1867': ('clearance', 213.75),
#  'T-BF-9033': ('clearance', 413.16),
#  'Y-IY-7527': ('clearance', 130.5),
#  'V-TY-3205': ('clearance', 220.79999999999998),
#  'N-UH-6452': ('clearance', 71.64),
#  'E-OI-3192': ('clearance', 959.04),
#  'L-ZA-1512': ('clearance', 1484.9),
#  'E-BG-7009': ('clearance', -69.48),
#  'L-BJ-2628': ('clearance', 56.25),
#  'T-YZ-6161': ('clearance', 436.76),
#  'Z-MC-7238': ('clearance', 64.96000000000001),
#  'U-MI-8391': ('clearance', 192.24),
#  'S-VA-8811': ('10% discount', 205.53191440393647),
#  'A-PX-4162': ('clearance', 1179.68),
#  'G-NH-1967': ('clearance', 48.93000000000001),
#  'N-QI-1274': ('clearance', 42.02),
#  'O-AE-7226': ('clearance', 263.2),
#  'D-FN-7792': ('clearance', 1332.0),
#  'F-WK-5963': ('clearance', 660.2800000000001),
#  'Y-XS-3690': ('clearance', 570.14),
#  'X-KQ-1029': ('clearance', -25.5),
#  'G-CD-3801': ('clearance', -65.7),
#  'Z-XI-2059': ('clearance', -6.03),
#  'V-GJ-3883': ('30% discount', 138.50123580201412),
#  'R-RY-4893': ('clearance', 264.18),
#  'V-CD-3618': ('clearance', 231.56000000000003),
#  'P-XD-4530': ('clearance', 250.04000000000002),
#  'G-LK-6361': ('clearance', 15.98),
#  'Y-BL-5539': ('clearance', 1244.6),
#  'K-TB-4875': ('clearance', 518.0500000000001),
#  'W-IS-9629': ('clearance', 692.64),
#  'B-BY-7269': ('clearance', 777.04),
#  'J-BI-7644': ('clearance', 184.23000000000002),
#  'G-CX-2725': ('clearance', 94.16),
#  'R-OL-2391': ('clearance', -67.12),
#  'Z-JW-7574': ('clearance', 80.0),
#  'P-YN-8729': ('clearance', 909.15),
#  'U-RM-4135': ('clearance', 316.16),
#  'X-QY-2374': ('clearance', 355.3),
#  'A-FZ-6100': ('clearance', 514.75),
#  'G-JQ-6403': ('clearance', 305.28),
#  'Q-HY-9091': ('clearance', -243.6),
#  'J-DD-7662': ('clearance', 177.46),
#  'E-RL-1889': ('clearance', -19.240000000000002),
#  'N-JP-1100': ('clearance', 270.98),
#  'R-LT-5089': ('clearance', 56.42),
#  'W-ZO-1845': ('clearance', 423.46),
#  'C-JL-1442': ('clearance', -22.83),
#  'G-UU-6949': ('clearance', 199.98),
#  'F-PO-7272': ('clearance', 88.83),
#  'I-GL-6610': ('10% discount', -29.005736052840014),
#  'X-ID-9671': ('clearance', 238.14000000000001),
#  'V-AQ-6719': ('clearance', 84.0),
#  'Z-YV-2221': ('clearance', 695.76),
#  'Z-QS-6372': ('clearance', 778.4100000000001),
#  'H-GU-7351': ('clearance', 904.23),
#  'X-AG-2359': ('clearance', 1865.59),
#  'I-YN-8333': ('clearance', 247.78),
#  'M-PS-8712': ('clearance', 1231.95),
#  'S-DA-5115': ('clearance', 649.9000000000001),
#  'Q-BK-6316': ('clearance', 1254.6),
#  'G-KW-4924': ('clearance', 14.780000000000001),
#  'Z-CU-4781': ('clearance', 464.82),
#  'Q-TN-8748': ('clearance', 179.76),
#  'Y-EE-8083': ('clearance', 265.44),
#  'L-XC-1217': ('clearance', -291.91999999999996),
#  'O-XT-1742': ('clearance', -27.450000000000003),
#  'F-AH-5804': ('10% discount', -26.228995441674044),
#  'T-ZT-2978': ('clearance', -329.8),
#  'G-LT-9180': ('clearance', 14.34),
#  'Y-LD-4459': ('clearance', 1349.76),
#  'G-HE-4490': ('clearance', 1215.49),
#  'N-YG-8340': ('clearance', 133.76),
#  'L-HZ-4479': ('clearance', 302.1),
#  'J-CQ-2719': ('clearance', 319.68),
#  'J-VA-1007': ('clearance', 256.36),
#  'K-BS-5169': ('clearance', 713.36),
#  'F-XV-6133': ('clearance', -262.36),
#  'E-OX-2711': ('clearance', 1585.3),
#  'T-XC-9979': ('clearance', 755.2199999999999),
#  'P-VV-5393': ('clearance', -210.42),
#  'T-IW-5257': ('clearance', 82.55),
#  'C-SE-3674': ('clearance', 170.57),
#  'O-GT-7504': ('clearance', -10.02),
#  'Z-TB-9462': ('clearance', 2149.48),
#  'O-IA-1193': ('clearance', -64.64),
#  'F-MO-5833': ('clearance', -93.9),
#  'I-VU-7657': ('clearance', -353.29),
#  'K-XB-5305': ('clearance', -138.18),
#  'Z-UG-7691': ('clearance', 297.15),
#  'P-DA-1516': ('clearance', -271.32000000000005),
#  'R-NJ-6378': ('clearance', 1615.82),
#  'C-KZ-7078': ('clearance', 491.78000000000003),
#  'T-QD-3931': ('clearance', 966.4599999999999),
#  'R-NF-8693': ('clearance', 965.52),
#  'B-SM-2491': ('clearance', 254.88000000000002),
#  'U-ZE-9425': ('clearance', 444.82),
#  'N-PA-9347': ('30% discount', 42.031907757588904),
#  'K-BA-2248': ('clearance', 151.2),
#  'N-QW-7274': ('30% discount', 104.30731380486958),
#  'N-SJ-5923': ('clearance', 892.84),
#  'R-YJ-2479': ('clearance', 1182.72),
#  'N-QV-3308': ('clearance', 1130.37),
#  'M-EX-2641': ('clearance', 85.67999999999999),
#  'U-CN-3844': ('clearance', 323.01000000000005),
#  'E-FI-6536': ('clearance', -6.97),
#  'E-HE-2227': ('clearance', 14.06),
#  'P-NJ-5281': ('clearance', -21.54),
#  'V-VC-3525': ('clearance', 388.85),
#  'I-XA-8435': ('clearance', 609.27),
#  'D-PS-1815': ('clearance', 109.12),
#  'L-HV-4554': ('clearance', 351.78),
#  'I-RH-6706': ('clearance', 718.0600000000001),
#  'J-WP-9712': ('clearance', 137.69),
#  'S-TI-1891': ('clearance', 560.66),
#  'U-TL-8641': ('clearance', -104.39999999999999),
#  'C-UN-2304': ('clearance', 137.08),
#  'M-CU-1292': ('clearance', 520.52),
#  'H-VS-2635': ('clearance', 563.58),
#  'X-OZ-4703': ('clearance', 72.9),
#  'E-EN-1284': ('clearance', 59.28),
#  'U-EU-2626': ('clearance', 229.07999999999998),
#  'T-VE-6532': ('clearance', -113.22000000000001),
#  'N-AC-3387': ('clearance', 1850.2),
#  'O-ZW-9955': ('clearance', 1051.83),
#  'C-WD-4443': ('clearance', 561.68),
#  'F-AT-3744': ('clearance', 412.92),
#  'Y-ON-6766': ('clearance', 434.41999999999996),
#  'O-PG-2851': ('clearance', -22.200000000000003),
#  'L-BF-9814': ('clearance', 100.32000000000001),
#  'T-TW-4480': ('clearance', 635.46),
#  'U-KG-7762': ('clearance', 1483.6200000000001),
#  'L-MJ-4296': ('clearance', 260.4),
#  'G-QK-5875': ('clearance', 1232.1299999999999),
#  'T-SN-1046': ('clearance', -36.24),
#  'B-RJ-6990': ('clearance', 824.5999999999999),
#  'N-OT-7496': ('clearance', 318.57),
#  'F-AV-5665': ('clearance', 453.20000000000005),
#  'V-XN-1504': ('clearance', 56.00000000000001),
#  'H-QA-2124': ('clearance', 334.8),
#  'R-BK-4052': ('clearance', 182.0),
#  'O-QF-6347': ('clearance', 145.35000000000002),
#  'V-EE-2258': ('clearance', 536.25),
#  'D-HK-4245': ('clearance', -22.610000000000003),
#  'H-HJ-1867': ('clearance', 370.98),
#  'K-ON-9090': ('clearance', 1627.19),
#  'Z-XA-4670': ('clearance', 216.38),
#  'G-PU-2875': ('clearance', 0.0),
#  'N-OM-1119': ('clearance', 139.6),
#  'M-BH-9376': ('clearance', 175.94),
#  'S-PV-3337': ('clearance', 74.64),
#  'F-JE-2988': ('clearance', -9.34),
#  'L-FW-5406': ('clearance', 280.78000000000003),
#  'V-FG-1655': ('clearance', -413.07),
#  'Z-SK-7825': ('clearance', 202.4),
#  'Q-AQ-3198': ('clearance', 174.99),
#  'R-VO-8743': ('clearance', -39.12),
#  'L-SQ-9785': ('clearance', 555.53),
#  'W-PY-2398': ('clearance', -55.160000000000004),
#  'W-CN-5278': ('clearance', 1545.84),
#  'J-VI-6452': ('clearance', 451.72),
#  'O-GE-1365': ('clearance', 83.30000000000001),
#  'Z-OZ-3259': ('clearance', 8.73),
#  'X-TC-1470': ('clearance', 1874.03),
#  'Q-WG-2167': ('clearance', 505.77),
#  'P-BF-2995': ('clearance', -52.52),
#  'L-UQ-5613': ('clearance', 29.31),
#  'W-TR-3892': ('clearance', 649.52),
#  'B-DN-7062': ('clearance', 1015.16),
#  'S-CE-5551': ('clearance', 429.44),
#  'R-AY-2169': ('clearance', 74.24),
#  'M-SQ-4808': ('clearance', 96.33),
#  'F-LG-2749': ('clearance', 33.48),
#  'M-SS-7592': ('clearance', 175.98),
#  'E-WA-9027': ('clearance', 248.88000000000002),
#  'S-KG-8955': ('clearance', 428.35),
#  'X-HM-2783': ('clearance', -32.4),
#  'A-WO-4928': ('clearance', 940.9499999999999),
#  'Z-UA-8949': ('clearance', 19.28),
#  'I-PX-1591': ('clearance', 504.90000000000003),
#  'Z-EY-1999': ('clearance', 697.2199999999999),
#  'F-ER-9631': ('clearance', 172.53),
#  'H-OZ-3657': ('10% discount', 1310.950430035057),
#  'T-XP-5034': ('clearance', 242.30999999999997),
#  'L-DP-9965': ('clearance', 50.050000000000004),
#  'R-KS-1397': ('clearance', 967.26),
#  'A-TG-3916': ('clearance', 817.09),
#  'P-ES-8327': ('clearance', 350.39),
#  'S-VP-4094': ('clearance', 176.41),
#  'A-MU-9777': ('clearance', 424.76),
#  'Z-PR-1912': ('clearance', 432.82000000000005),
#  'Q-SE-7366': ('clearance', -57.2),
#  'J-WJ-5883': ('clearance', 23.970000000000002),
#  'Y-VO-9847': ('clearance', 487.83),
#  'Z-IJ-7112': ('clearance', -415.81),
#  'R-GH-8829': ('clearance', 554.88),
#  'M-FD-4719': ('clearance', -26.61),
#  'K-VN-1736': ('clearance', -190.47),
#  'Y-VJ-9997': ('clearance', 865.0),
#  'C-WK-9427': ('clearance', 1569.46),
#  'C-FL-8371': ('clearance', 254.17999999999998),
#  'F-GA-3047': ('clearance', -98.21000000000001),
#  'K-AO-2166': ('clearance', 1239.8500000000001),
#  'N-PP-3343': ('clearance', -54.15),
#  'F-RH-9053': ('clearance', 17.13),
#  'M-GO-3945': ('clearance', 989.52),
#  'U-RV-3517': ('clearance', -89.12),
#  'I-YG-4884': ('clearance', 307.26000000000005),
#  'Z-RL-7383': ('clearance', -78.80000000000001),
#  'H-OD-9399': ('clearance', -158.72),
#  'O-XK-6155': ('clearance', -41.510000000000005),
#  'Y-ZU-9699': ('clearance', 99.4),
#  'N-KB-6417': ('clearance', 824.46),
#  'R-SP-1710': ('clearance', -228.16),
#  'W-XU-3932': ('clearance', 49.68),
#  'R-BR-9371': ('clearance', 1341.1999999999998),
#  'K-JV-3863': ('clearance', 843.64),
#  'Q-SV-6963': ('clearance', 690.84),
#  'F-XZ-2553': ('clearance', 252.8),
#  'C-AC-5240': ('clearance', 409.83),
#  'A-QE-6402': ('clearance', 168.23999999999998),
#  'Y-SU-3286': ('clearance', 1989.7299999999998),
#  'Y-GZ-5231': ('clearance', 612.15),
#  'O-QY-5039': ('clearance', 186.45000000000002),
#  'W-OE-9671': ('clearance', 105.34),
#  'T-KU-9560': ('10% discount', 505.3369556910393),
#  'D-FJ-4058': ('clearance', 106.12),
#  'W-XE-1110': ('clearance', 896.68),
#  'U-ZX-8503': ('clearance', 137.27),
#  'B-AI-7560': ('10% discount', 596.9195971942303),
#  'D-TH-4946': ('clearance', 1782.86),
#  'O-JJ-9746': ('clearance', -58.800000000000004),
#  'Z-GW-9501': ('clearance', 1033.6799999999998),
#  'K-CR-7336': ('clearance', 2.81),
#  'W-SO-2017': ('clearance', 482.82),
#  'U-IR-2378': ('clearance', 796.0),
#  'L-GZ-6808': ('clearance', -179.01000000000002),
#  'W-MV-4602': ('clearance', 737.04),
#  'W-CK-9340': ('20% discount', 25.829106487920306),
#  'Z-WZ-1633': ('clearance', 87.96),
#  'U-KL-9512': ('clearance', 493.17),
#  'D-JG-8777': ('clearance', 1065.03),
#  'P-VS-6295': ('clearance', -95.4),
#  'Q-MI-8636': ('clearance', 5.8),
#  'M-YG-5769': ('clearance', 53.879999999999995),
#  'L-YP-8362': ('clearance', 403.8),
#  'I-PZ-9753': ('clearance', -282.48),
#  'M-AB-9780': ('clearance', 412.56),
#  'B-VR-1120': ('clearance', -46.199999999999996),
#  'H-WE-2251': ('clearance', 540.4399999999999),
#  'I-JL-8363': ('clearance', 704.9300000000001),
#  'Y-GG-2787': ('clearance', -2.86),
#  'U-DZ-1652': ('clearance', 600.06),
#  'Y-VO-8506': ('clearance', 327.54),
#  'F-JS-4144': ('clearance', -79.22),
#  'W-SR-9746': ('clearance', 513.7),
#  'B-JV-9761': ('clearance', 625.24),
#  'P-CU-2232': ('clearance', 77.44),
#  'W-OP-7755': ('clearance', 696.44),
#  'A-UA-2169': ('clearance', 99.2),
#  'S-HV-6452': ('clearance', 68.11),
#  'J-GL-3855': ('clearance', 1300.6),
#  'A-HC-4612': ('clearance', 255.29999999999998),
#  'O-KX-3023': ('clearance', 722.1),
#  'G-NY-5481': ('clearance', 1066.5),
#  'L-VM-4780': ('clearance', 47.64),
#  'W-AC-2284': ('clearance', 1224.3),
#  'I-KJ-8457': ('clearance', 38.43),
#  'X-GA-5709': ('clearance', 247.18),
#  'R-FM-2582': ('clearance', 522.0),
#  'M-HA-7556': ('clearance', 882.2800000000001),
#  'R-RW-5567': ('clearance', 50.96),
#  'K-LU-4402': ('clearance', 350.28),
#  'X-OE-5655': ('clearance', -100.75),
#  'R-RA-6569': ('clearance', 1122.95),
#  'E-SM-7455': ('clearance', -51.84),
#  'N-AL-7552': ('clearance', 326.15999999999997),
#  'L-QY-5877': ('clearance', 39.38),
#  'W-BF-8955': ('clearance', 286.34),
#  'N-RY-7032': ('clearance', 551.9499999999999),
#  'D-DQ-1275': ('clearance', -19.55),
#  'M-IA-2446': ('clearance', 264.25),
#  'G-KI-1090': ('clearance', 113.22000000000001),
#  'A-RC-2037': ('clearance', 690.65),
#  'J-FE-9680': ('clearance', 137.7),
#  'G-LG-8720': ('clearance', 14.43),
#  'N-QN-9939': ('clearance', 324.89000000000004),
#  'F-WD-9490': ('clearance', -388.05),
#  'E-CT-8118': ('clearance', 1391.04),
#  'O-DG-5356': ('clearance', -206.42999999999998),
#  'R-IS-1606': ('clearance', 169.92),
#  'C-JH-6887': ('clearance', 556.16),
#  'N-JI-3592': ('clearance', 42.95),
#  'L-MV-9726': ('clearance', 140.85),
#  'Y-XI-8957': ('clearance', -118.58),
#  'C-ZQ-9129': ('clearance', 333.20000000000005),
#  'O-NB-2960': ('clearance', 42.059999999999995),
#  'V-NM-9758': ('clearance', 227.60000000000002),
#  'W-FV-4483': ('clearance', 113.23),
#  'F-TL-6042': ('clearance', 725.9),
#  'K-UD-8380': ('clearance', 1664.7),
#  'K-FA-1433': ('clearance', 86.32000000000001),
#  'Q-LZ-9746': ('clearance', 105.00000000000001),
#  'J-MA-2099': ('clearance', 124.32000000000001),
#  'Q-NE-5804': ('clearance', 315.48),
#  'S-RB-5275': ('clearance', 269.28000000000003),
#  'D-SU-4713': ('clearance', -139.75),
#  'V-FB-4334': ('clearance', 1097.82),
#  'Z-KL-8786': ('clearance', 415.40000000000003),
#  'S-JT-3840': ('clearance', 1295.91),
#  'Y-SG-7529': ('clearance', 405.0),
#  'P-EC-6814': ('clearance', 154.79000000000002),
#  'C-RV-8084': ('clearance', -19.8),
#  'E-RI-3320': ('clearance', 379.62),
#  'V-KD-2849': ('clearance', 387.27000000000004),
#  'L-UL-6321': ('clearance', -19.02),
#  'Q-ZC-2316': ('clearance', -3.75),
#  'M-BT-7811': ('clearance', 1186.4299999999998),
#  'X-NI-8203': ('clearance', 448.90999999999997),
#  'Q-NL-4480': ('clearance', 133.0),
#  'T-GG-7947': ('clearance', 683.06),
#  'P-JJ-9231': ('clearance', 1073.8),
#  'L-LK-3170': ('clearance', 373.5),
#  'C-UY-9265': ('clearance', 639.85),
#  'L-RN-9219': ('clearance', 8.97),
#  'F-PH-8792': ('clearance', 171.38),
#  'Q-FH-1566': ('clearance', 457.2),
#  'R-PM-6493': ('clearance', 37.940000000000005),
#  'S-ZO-4890': ('clearance', 339.47999999999996),
#  'U-CC-9220': ('clearance', -286.2),
#  'E-DG-6809': ('clearance', 538.02),
#  'I-CC-7117': ('clearance', 370.76),
#  'F-LF-4082': ('clearance', 641.9200000000001),
#  'X-RQ-9870': ('clearance', -67.69000000000001),
#  'R-QS-6275': ('clearance', 438.31),
#  'W-AB-3549': ('clearance', 426.62),
#  'Y-OP-9882': ('clearance', 388.5),
#  'S-OR-9586': ('clearance', 37.8),
#  'W-AJ-3222': ('clearance', 334.74),
#  'K-WV-5010': ('clearance', 419.1),
#  'V-IV-8170': ('clearance', 367.68),
#  'W-BE-6199': ('clearance', 208.32),
#  'F-PB-1667': ('clearance', 260.01),
#  'A-DT-7692': ('clearance', -27.39),
#  'O-SS-7787': ('clearance', 2112.66),
#  'P-KY-8314': ('clearance', 838.88),
#  'C-XD-8590': ('clearance', 97.95),
#  'Z-PY-4912': ('clearance', 53.22),
#  'K-TF-3198': ('clearance', -115.43),
#  'N-OZ-8049': ('clearance', 1054.34),
#  'V-MP-6813': ('clearance', 184.32),
#  'A-PW-6358': ('clearance', 153.72),
#  'W-GA-4009': ('clearance', 560.59),
#  'O-SB-2156': ('clearance', 811.84),
#  'M-NO-1303': ('clearance', -55.32),
#  'K-EQ-5240': ('clearance', 370.5),
#  'V-HV-4054': ('clearance', 277.15999999999997),
#  'Y-DL-4303': ('clearance', 263.76000000000005),
#  'P-VJ-7391': ('clearance', 111.52000000000001),
#  'C-MS-1050': ('clearance', 413.65999999999997),
#  'K-LO-1445': ('clearance', 1883.6799999999998),
#  'G-IQ-4953': ('clearance', 488.16),
#  'I-QM-1354': ('clearance', 190.95000000000002),
#  'G-YG-2113': ('clearance', 1545.96),
#  'Z-QC-3676': ('clearance', 1141.73),
#  'B-ZT-9524': ('clearance', 196.46),
#  'X-QA-5570': ('30% discount', 88.97099557485095),
#  'E-HW-3276': ('clearance', 16.3),
#  'R-NS-3166': ('clearance', 413.0),
#  'W-CM-5222': ('clearance', 500.82),
#  'F-AQ-9860': ('clearance', -277.4),
#  'E-NT-6154': ('clearance', 246.4),
#  'X-MI-6612': ('clearance', 978.12),
#  'V-RZ-4544': ('clearance', 641.5200000000001),
#  'Y-FA-6675': ('clearance', 1768.52),
#  'J-WR-3485': ('clearance', 1151.8799999999999),
#  'P-LJ-6038': ('clearance', -14.96),
#  'B-WG-1413': ('clearance', 395.64),
#  'L-ZD-7155': ('clearance', 243.29999999999998),
#  'N-SV-6678': ('clearance', -209.3),
#  'W-BU-8738': ('clearance', 314.16),
#  'W-JI-3526': ('clearance', 967.61),
#  'D-CR-9813': ('clearance', -126.36),
#  'B-IJ-9445': ('clearance', 524.6899999999999),
#  'Z-FX-9553': ('clearance', 558.6),
#  'B-TK-7890': ('clearance', 746.64),
#  'Z-MF-7865': ('clearance', 155.1),
#  'W-SA-7846': ('clearance', 331.7),
#  'D-EV-1704': ('clearance', 946.0),
#  'X-TC-3691': ('clearance', 175.76999999999998),
#  'I-FO-9574': ('clearance', -48.580000000000005),
#  'Q-EZ-8939': ('clearance', 768.75),
#  'P-JY-1259': ('clearance', 76.23),
#  'R-RU-1367': ('clearance', 652.0500000000001),
#  'X-YJ-7979': ('clearance', 114.53),
#  'E-BD-7370': ('10% discount', 777.7178104770464),
#  'O-LH-5398': ('clearance', 700.77),
#  'D-XJ-3254': ('clearance', -124.46000000000001),
#  'G-GR-8404': ('clearance', 169.1),
#  'H-FL-8078': ('clearance', 630.63),
#  'U-PI-6577': ('clearance', 104.55),
#  'R-WX-8381': ('clearance', 1721.44),
#  'L-IX-7417': ('clearance', 1312.15),
#  'I-ZA-6675': ('clearance', 56.07000000000001),
#  'M-CR-8922': ('clearance', -32.800000000000004),
#  'M-MX-9717': ('clearance', 99.4),
#  'A-BS-1154': ('clearance', 386.88),
#  'S-YV-9937': ('clearance', 656.26),
#  'O-JK-6274': ('clearance', 769.08),
#  'Y-GU-9800': ('clearance', 391.5),
#  'A-XC-7595': ('clearance', 362.4),
#  'K-PX-6486': ('clearance', 160.11),
#  'P-NI-5028': ('clearance', 336.18),
#  'F-LW-8301': ('clearance', 189.0),
#  'N-CE-9826': ('clearance', 306.27),
#  'Z-KO-3559': ('clearance', 357.05),
#  'Q-PE-8050': ('clearance', 141.6),
#  'Q-OI-2358': ('clearance', 1094.4),
#  'V-SE-2530': ('clearance', 1659.8400000000001),
#  'V-NK-8248': ('clearance', 669.12),
#  'K-JU-5114': ('clearance', 917.28),
#  'W-CL-6822': ('clearance', 533.76),
#  'Q-HT-3693': ('clearance', 49.0),
#  'H-DS-4008': ('clearance', 207.46),
#  'M-CT-4015': ('clearance', 156.75),
#  'G-LF-5499': ('clearance', -172.44),
#  'T-TH-7159': ('clearance', 309.56),
#  'N-NF-1974': ('clearance', 1003.2900000000001),
#  'X-GQ-1962': ('clearance', 359.0),
#  'F-GU-7350': ('10% discount', 683.3870129251957),
#  'G-TT-5236': ('clearance', 122.0),
#  'J-RC-6893': ('clearance', 459.04),
#  'Q-QH-3784': ('clearance', 286.52),
#  'Y-EU-9563': ('clearance', 103.73),
#  'N-JL-9022': ('clearance', 138.78),
#  'W-RH-4950': ('clearance', -140.3),
#  'H-ZN-5393': ('clearance', -90.4),
#  'Y-EC-3170': ('clearance', 220.18),
#  'R-ZR-3721': ('clearance', 788.5),
#  'F-ZN-3570': ('clearance', 31.780000000000005),
#  'H-LN-2080': ('clearance', 1562.88),
#  'W-JP-3738': ('clearance', 881.9200000000001),
#  'V-HX-5898': ('clearance', 253.84),
#  'N-PM-5979': ('clearance', 409.37),
#  'A-ZQ-3882': ('clearance', 84.5),
#  'R-PF-4450': ('clearance', 26.1),
#  'O-YI-2139': ('clearance', 469.26000000000005),
#  'L-LN-1938': ('clearance', 792.12),
#  'A-JA-8493': ('clearance', 43.65),
#  'X-EC-1552': ('clearance', 14.219999999999999),
#  'B-HU-1694': ('clearance', 122.59),
#  'M-VZ-6142': ('clearance', 439.2),
#  'F-GK-6939': ('clearance', 205.04),
#  'B-SO-2821': ('clearance', 841.6500000000001),
#  'I-YY-3323': ('clearance', 74.86),
#  'P-TP-5601': ('clearance', 641.52),
#  'I-MW-9293': ('clearance', 1169.48),
#  'H-RH-6859': ('clearance', 405.52),
#  'Q-RP-2758': ('clearance', 145.44),
#  'E-DZ-9959': ('clearance', 8.4),
#  'T-OH-8016': ('clearance', 72.11999999999999),
#  'J-PM-5003': ('clearance', -94.16),
#  'C-KF-1267': ('clearance', 127.08999999999999),
#  'T-NN-1487': ('clearance', -23.04),
#  'Y-NI-9589': ('clearance', 693.1),
#  'T-QM-9407': ('10% discount', 277.26473057403734),
#  'O-KI-9374': ('clearance', -200.57),
#  'K-MA-1179': ('clearance', 140.1),
#  'B-IG-5830': ('clearance', 850.84),
#  'I-FJ-6663': ('clearance', 1166.41),
#  'K-VC-3922': ('clearance', 184.45),
#  'E-KG-3457': ('clearance', 253.74999999999997),
#  'J-SM-9247': ('clearance', 1621.2),
#  'P-XS-6836': ('clearance', 591.48),
#  'B-EU-3802': ('10% discount', 703.3095425514567),
#  'H-QD-3325': ('clearance', 366.0),
#  'W-XV-7510': ('clearance', 603.5),
#  'Z-NS-9953': ('clearance', 549.54),
#  'D-RR-1120': ('clearance', 290.46999999999997),
#  'F-GL-4157': ('clearance', 477.0),
#  'F-EG-2832': ('clearance', 1193.4),
#  'Y-GJ-4474': ('clearance', 342.21),
#  'J-KP-7135': ('clearance', 194.70000000000002),
#  'Q-SS-1561': ('clearance', -55.77),
#  'L-PW-8810': ('clearance', 607.87),
#  'N-DW-2894': ('clearance', 813.9599999999999),
#  'V-AO-4803': ('clearance', 371.6),
#  'I-FX-2284': ('clearance', 90.50999999999999),
#  'J-DY-1638': ('clearance', 564.0),
#  'F-CG-4063': ('clearance', 10.84),
#  'F-PS-6539': ('clearance', 594.0),
#  'P-FW-8620': ('clearance', -15.9),
#  'A-EI-5586': ('clearance', 288.40000000000003),
#  'F-RM-2051': ('10% discount', 651.3711329574967),
#  'V-GV-4127': ('clearance', -38.24),
#  'N-UE-7322': ('clearance', 847.1),
#  'L-NR-9019': ('clearance', 634.9),
#  'Q-NE-3929': ('clearance', 84.4),
#  'F-ME-3067': ('clearance', 105.83999999999999),
#  'Q-VS-5336': ('clearance', 96.17999999999999),
#  'C-AS-4165': ('clearance', 173.04000000000002),
#  'I-BU-9659': ('clearance', 194.26),
#  'Z-LX-3897': ('clearance', 54.48),
#  'Z-JG-4099': ('clearance', 332.64),
#  'K-QS-5254': ('clearance', -98.34),
#  'U-YN-9773': ('clearance', -48.620000000000005),
#  'N-ZK-9577': ('clearance', 1525.08),
#  'G-JT-1179': ('clearance', 645.15),
#  'G-EI-5412': ('clearance', 696.6400000000001),
#  'K-ZT-4817': ('clearance', 198.75),
#  'I-CL-7498': ('clearance', 171.18),
#  'D-BA-8495': ('clearance', 246.76),
#  'H-UL-9884': ('clearance', 187.34),
#  'T-NK-7718': ('clearance', 3.35),
#  'D-LM-9508': ('clearance', 600.48),
#  'V-IK-6055': ('clearance', 31.720000000000002),
#  'G-VU-2329': ('clearance', 18.32),
#  'W-HB-4602': ('clearance', 255.73000000000002),
#  'W-EQ-5559': ('clearance', -105.80000000000001),
#  'K-QT-2559': ('clearance', 239.75),
#  'R-VH-5559': ('clearance', 294.7),
#  'E-YX-1896': ('clearance', 0.0),
#  'K-JR-5708': ('clearance', -32.1),
#  'G-LM-8387': ('clearance', 132.84),
#  'Z-FS-8887': ('clearance', 1419.6),
#  'S-AI-7506': ('clearance', 686.28),
#  'N-ZE-5023': ('clearance', -110.5),
#  'A-AU-5110': ('clearance', 583.0999999999999),
#  'C-JW-8483': ('clearance', -79.2),
#  'P-BC-2351': ('clearance', 82.18),
#  'N-QN-5001': ('clearance', 47.3),
#  'T-TA-4606': ('clearance', 559.91),
#  'W-BT-4686': ('clearance', 488.43),
#  'B-FR-6669': ('clearance', 361.05),
#  'J-FR-1266': ('clearance', 314.84000000000003),
#  'N-RF-4243': ('clearance', 319.0),
#  'V-ND-5925': ('clearance', 66.66),
#  'I-IA-9348': ('clearance', 285.0),
#  'W-IQ-4649': ('clearance', 819.06),
#  'X-OA-3560': ('clearance', 1594.02),
#  'R-BK-4558': ('clearance', 386.76),
#  'K-BX-3964': ('clearance', 391.14000000000004),
#  'M-NA-7367': ('clearance', -189.02),
#  'R-KQ-6875': ('clearance', -122.2),
#  'X-FQ-9029': ('clearance', 354.64),
#  'E-ET-6588': ('clearance', 66.95),
#  'W-LZ-4610': ('clearance', 361.8),
#  'S-UL-7284': ('clearance', 196.98),
#  'G-PW-8634': ('clearance', 241.02),
#  'N-JD-6391': ('clearance', -7.8500000000000005),
#  'A-AJ-2494': ('clearance', 455.38999999999993),
#  'N-HS-1093': ('clearance', 146.16),
#  'S-PR-6129': ('clearance', 465.0),
#  'P-CW-8255': ('clearance', 159.63000000000002),
#  'F-GX-2352': ('clearance', 987.6999999999999),
#  'R-RJ-1155': ('clearance', 253.64000000000001),
#  'Y-MD-6362': ('clearance', 694.72),
#  'M-PH-1939': ('clearance', 87.71),
#  'W-JF-3199': ('clearance', 478.5),
#  'U-GW-3186': ('clearance', 858.0),
#  'Z-UM-5285': ('clearance', -89.64),
#  'K-IU-3174': ('clearance', 607.75),
#  'O-ZD-7455': ('clearance', 552.96),
#  'T-YP-1893': ('clearance', 1299.6499999999999),
#  'M-MF-5955': ('clearance', -47.800000000000004),
#  'D-BE-9442': ('clearance', 956.47),
#  'D-WR-8833': ('clearance', 0.0),
#  'A-YD-8460': ('clearance', 184.8),
#  'N-RN-8653': ('clearance', 93.52000000000001),
#  'A-GP-4069': ('clearance', 385.82),
#  'H-MA-7813': ('clearance', 241.49),
#  'Y-YF-9192': ('clearance', 2015.9299999999998),
#  'S-PU-7294': ('clearance', 528.96),
#  'K-RO-1123': ('clearance', 1661.27),
#  'I-SY-8702': ('clearance', 980.1),
#  'V-VO-6903': ('clearance', -150.72),
#  'H-LG-7866': ('clearance', 293.76000000000005),
#  'R-FK-8169': ('clearance', 81.53),
#  'V-EA-7374': ('clearance', 1225.12),
#  'L-HX-1905': ('clearance', -323.07),
#  'O-NT-7047': ('clearance', 582.59),
#  'V-IS-2562': ('clearance', 916.0),
#  'A-PJ-5331': ('clearance', 643.72),
#  'R-FL-8063': ('clearance', 130.18),
#  'G-KN-8867': ('clearance', -50.64),
#  'A-JY-9320': ('clearance', -22.84),
#  'T-WI-1201': ('clearance', 461.84000000000003),
#  'H-GS-9244': ('clearance', 905.28),
#  'T-KV-5337': ('10% discount', -47.08297921963732),
#  'N-VL-9075': ('clearance', 302.63),
#  'C-QK-5950': ('clearance', 593.75),
#  'A-EQ-7294': ('clearance', 596.84),
#  'O-SK-9358': ('clearance', 354.28000000000003),
#  'I-JO-8866': ('clearance', 1009.0500000000001),
#  'N-PE-8349': ('clearance', 437.92),
#  'Y-IG-5746': ('clearance', 632.25),
#  'U-AU-1304': ('clearance', 136.78),
#  'D-KY-1854': ('clearance', -34.800000000000004),
#  'Z-ZD-9998': ('clearance', 83.16),
#  'Q-AX-6430': ('clearance', 683.76),
#  'F-YD-4982': ('10% discount', 423.33817720024024),
#  'V-MU-9407': ('clearance', 1048.8),
#  'I-OW-1640': ('clearance', 473.09999999999997),
#  'U-VL-2044': ('clearance', 804.27),
#  'L-GD-5514': ('clearance', 20.849999999999998),
#  'J-KB-3858': ('clearance', 416.83),
#  'C-UM-8975': ('clearance', 1958.2199999999998),
#  'M-GO-3227': ('clearance', 349.35),
#  'J-QS-2374': ('clearance', 951.52),
#  'C-RA-3149': ('clearance', -46.800000000000004),
#  'L-XV-9762': ('clearance', 835.12),
#  'P-ON-8855': ('clearance', 249.68999999999997),
#  'A-PT-7346': ('clearance', 1274.0),
#  'I-WC-2507': ('clearance', 1108.6),
#  'Q-GM-1535': ('clearance', 391.16),
#  'Z-JC-2677': ('clearance', -221.43),
#  'C-ZE-7614': ('clearance', 386.90000000000003),
#  'V-OO-3101': ('clearance', -52.32),
#  'Z-ZX-9451': ('clearance', -156.96),
#  'D-TT-5739': ('clearance', 413.6),
#  'H-GT-2618': ('10% discount', 34.49006099155486),
#  'T-CT-5824': ('clearance', 553.35),
#  'T-JO-1528': ('clearance', 486.42),
#  'M-OU-3907': ('clearance', 453.90000000000003),
#  'I-GK-3832': ('clearance', 90.47999999999999),
#  'R-DQ-9552': ('clearance', 1215.08),
#  'X-SC-7695': ('clearance', 436.05),
#  'J-CC-4853': ('clearance', 149.76),
#  'N-OF-6557': ('clearance', -110.24000000000001),
#  'T-KG-4722': ('clearance', 1119.3999999999999),
#  'L-PR-4157': ('clearance', 107.52),
#  'R-VX-2388': ('clearance', 68.60000000000001),
#  'X-TO-9502': ('clearance', 347.27),
#  'P-DG-4259': ('clearance', 7.62),
#  'D-KL-1093': ('clearance', -126.88000000000001),
#  'E-ZN-9370': ('clearance', 271.46),
#  'J-WF-9269': ('clearance', 104.32000000000001),
#  'X-KM-2688': ('clearance', 258.3),
#  'T-VM-3403': ('clearance', 128.86),
#  'G-VL-9466': ('clearance', 1489.5),
#  'E-UH-4506': ('clearance', 28.05),
#  'C-MF-1879': ('clearance', -104.88),
#  'B-GF-7806': ('clearance', 1759.38),
#  'Q-FP-9163': ('clearance', -182.7),
#  'L-LG-1489': ('clearance', 164.4),
#  'O-BA-7980': ('clearance', 0.0),
#  'Y-DF-7813': ('clearance', -36.1),
#  'A-UR-6896': ('clearance', 336.68),
#  'W-SN-3392': ('20% discount', 229.60465473450955),
#  'A-JP-2692': ('clearance', -27.37),
#  'Q-SR-1406': ('clearance', 1024.1),
#  'J-VK-3942': ('clearance', 347.6),
#  'L-RA-4879': ('clearance', 1003.4399999999999),
#  'R-XH-6762': ('clearance', -20.2),
#  'T-UT-5349': ('clearance', 19.200000000000003),
#  'J-FV-8277': ('clearance', 731.12),
#  'R-PB-4653': ('clearance', 1149.5700000000002),
#  'K-IC-9035': ('clearance', 232.20000000000002),
#  'C-HI-3795': ('clearance', 139.39000000000001),
#  'B-ET-8556': ('clearance', 1111.5),
#  'L-WF-3306': ('clearance', 495.94000000000005),
#  'M-VH-5061': ('clearance', 375.13),
#  'O-XU-1512': ('clearance', 794.13),
#  'A-YC-1691': ('clearance', -128.24),
#  'Y-EA-3547': ('clearance', 273.28000000000003),
#  'V-FR-3192': ('clearance', 650.24),
#  'R-MO-2581': ('clearance', 185.17999999999998),
#  'Q-CF-5310': ('clearance', 508.04),
#  'W-AS-6290': ('20% discount', 466.7937754036392),
#  'M-XJ-2815': ('clearance', 1492.34),
#  'G-EM-3141': ('clearance', 297.71999999999997),
#  'M-PW-6781': ('clearance', 224.25),
#  'P-TV-8890': ('clearance', 414.78),
#  'V-ES-9890': ('clearance', 985.47),
#  'Z-HU-3115': ('clearance', -27.959999999999997),
#  'A-OI-8235': ('clearance', -9.12),
#  'T-BY-1016': ('clearance', 369.41),
#  'G-LQ-1247': ('clearance', 228.54000000000002),
#  'V-YA-9473': ('clearance', 2175.3199999999997),
#  'A-KZ-8289': ('clearance', 802.0),
#  'D-KO-8286': ('clearance', 199.5),
#  'F-AG-6950': ('clearance', 27.150000000000002),
#  'L-PN-4484': ('clearance', 409.40000000000003),
#  'X-HC-1691': ('clearance', 427.42),
#  'H-YD-4681': ('clearance', -335.25),
#  'E-AT-1027': ('clearance', 653.66),
#  'F-LB-7260': ('clearance', 9.08),
#  'A-AL-1592': ('clearance', 485.25),
#  'C-LF-5519': ('clearance', -86.67),
#  'O-OQ-3528': ('20% discount', -52.146917301409914),
#  'E-JQ-2171': ('10% discount', 468.6571729795028),
#  'U-VJ-5784': ('clearance', 1626.58),
#  'J-MX-9121': ('clearance', 725.67),
#  'O-ZV-7417': ('clearance', 444.21000000000004),
#  'B-DC-7598': ('clearance', -114.11999999999999),
#  'N-HB-8893': ('clearance', -2.52),
#  'Q-UL-1851': ('clearance', 645.12),
#  'Z-VU-9832': ('clearance', 1123.78),
#  'D-KP-2377': ('clearance', -130.15),
#  'I-XW-4722': ('10% discount', 418.2475372091968),
#  'X-DL-5492': ('clearance', 1135.68),
#  'Q-YA-4944': ('clearance', 113.23),
#  'C-KR-6460': ('clearance', 1300.32),
#  'Q-MD-5390': ('clearance', 678.3),
#  'I-YU-9141': ('clearance', 596.88),
#  'E-ZR-2386': ('clearance', 150.15),
#  'Z-FO-1571': ('clearance', 452.88),
#  'Y-SW-4304': ('clearance', -95.39999999999999),
#  'M-IG-4294': ('clearance', 200.0),
#  'S-HI-7432': ('clearance', 908.96),
#  'I-SA-8725': ('clearance', 246.24),
#  'J-IZ-9243': ('clearance', 504.0),
#  'L-VF-4379': ('clearance', 770.44),
#  'I-JS-2815': ('clearance', 262.57),
#  'Y-LQ-2674': ('clearance', 793.75),
#  'V-KQ-9238': ('clearance', 839.3000000000001),
#  'F-DO-4253': ('clearance', 23.380000000000003),
#  'N-DI-7374': ('clearance', -92.16),
#  'Z-HO-8186': ('clearance', 526.87),
#  'E-EB-4810': ('clearance', 40.0),
#  'Q-FW-2977': ('clearance', 43.28),
#  'A-HS-6958': ('clearance', 193.59),
#  'T-XW-8783': ('clearance', 263.12),
#  'J-MV-3117': ('clearance', -217.36),
#  'W-TC-5891': ('clearance', 278.12),
#  'X-VS-3509': ('clearance', 81.89999999999999),
#  'V-SC-1268': ('clearance', -232.0),
#  'E-FH-2645': ('clearance', 436.15000000000003),
#  'S-GG-2282': ('clearance', 87.49000000000001),
#  'T-QZ-9201': ('clearance', 2150.58),
#  'Y-AP-9462': ('clearance', -14.76),
#  'Y-IV-4687': ('clearance', 228.6),
#  'R-GC-6799': ('clearance', 840.84),
#  'F-TB-1419': ('clearance', 689.0400000000001),
#  'N-WH-1362': ('clearance', 1671.1),
#  'W-JB-7267': ('clearance', 686.7),
#  'H-CF-3322': ('clearance', 377.6),
#  'B-SB-6120': ('10% discount', 211.10960765373557),
#  'Z-HU-8610': ('clearance', 1282.26),
#  'L-XE-5699': ('clearance', 934.4),
#  'L-GI-1308': ('clearance', 807.23),
#  'F-HW-7085': ('clearance', 562.32),
#  'V-HQ-6008': ('clearance', 22.77),
#  'X-ZT-1439': ('clearance', 156.6),
#  'K-JT-2053': ('clearance', -87.89),
#  'N-ON-5785': ('30% discount', 71.23953902932622),
#  ...}

# %%
'Con el uso del dictionary anterior ahora podemos asociar el resultado de ese análisis a nuestro data frame lossing_product, en este caso extraemos la decisión que se tomo'
lossing_product['decision'] = lossing_product['sku'].map(lambda x: decision_losing_products[x][0])

# %%
lossing_product['decision'].value_counts()
# Out:
# decision
# clearance       5473
# 10% discount      81
# 30% discount      38
# 20% discount      18
# Name: count, dtype: int64

# %%
'Con el uso del dictionary anterior ahora podemos asociar el resultado de ese análisis a nuestro data frame lossing_product, en este caso extraemos la rentabilidad que se calculó'
lossing_product['profit'] = lossing_product['sku'].map(lambda x: decision_losing_products[x][1])

# %%
lossing_product['profit'].describe()
# Out:
# count    5610.000000
# mean      414.591557
# std       477.501740
# min      -496.260000
# 25%        72.390000
# 50%       278.975000
# 75%       639.772500
# max      2552.820000
# Name: profit, dtype: float64

# %% [markdown]
# # Generate the reports

# %%
'Creamos un nuevo data frame'
out_df = pd.DataFrame()

# %%
'Incluimos la columna de sku de nuestro df al data frame creado.'
out_df['sku'] = df['sku']

# %%
out_df.head()
# Out:
#          sku
# 0  L-FW-8504
# 1  N-KI-3619
# 2  C-TS-9945
# 3  N-QB-3444
# 4  W-IF-7282

# %%
'Esta función separa el SKU por el guión y nos devuelve el tipo de producto'
def product_category(row):
  return row['sku'].split('-')[0]

# %%
'Creamos la columna de categoría de producto'
out_df['product_category'] = out_df.apply(product_category, axis=1)

# %%
'para todos aquellos SKUs que no tienen valor de decision ya que eran rentables desde el principio, se les asigna el valor de ok'
from textwrap import fill
out_df['decision'] = out_df['sku'].map(lambda x: decision_losing_products.get(x,(np.nan,np.nan))[0]).fillna('ok')

# %%
'Copiamos la rentabilidad calculada según descuento/clearance'
out_df['final_profit'] = out_df['sku'].map(lambda x: decision_losing_products.get(x,(np.nan,np.nan))[1])

# %%
'Para los SKUs rentables copiamos la rentabilidad inicial con su precio de venta full.'
out_df['final_profit'][out_df['final_profit'].isna()] = df['discount_profit']
# Out:
# /tmp/ipython-input-3130191619.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   out_df['final_profit'][out_df['final_profit'].isna()] = df['discount_profit']
# /tmp/ipython-input-3130191619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_df['final_profit'][out_df['final_profit'].isna()] = df['discount_profit']

# %%
out_df['final_profit']
# Out:
# 0        1597.590000
# 1        2386.606600
# 2         152.680000
# 3        3506.705326
# 4         552.963298
#             ...
# 19995    1066.402463
# 19996     659.511055
# 19997    3086.934841
# 19998     360.948764
# 19999     452.760000
# Name: final_profit, Length: 20000, dtype: float64

# %%
print(f'Best escenario profit {out_df['final_profit'].sum():,.0f} $')
# Out:
# Best escenario profit 22,204,381 $

# %% [markdown]
# # Create columns for report

# %% [markdown]
# ## Excel notebook

# %%
'Nos aseguramos de tener instalada una librería para poder manipular excel con pandas'
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
from openpyxl import Workbook
from openpyxl.styles import PatternFill

# %%
'Determinamos de qué color serán rellenas las celdas según la estrategia de ventas de acuerdo a las instrucciones dadas'
fill_clear = PatternFill(start_color='FFC9C9',
                   end_color='FFC9C9',
                   fill_type='solid')
fill_discount = PatternFill(start_color='FEF9C2',
                   end_color='FEF9C2',
                   fill_type='solid')

# %%
'Creamos el archivo de excel. Es importante recordar que Excel empieza a contar desde el 1 y en el caso de filas la 1 siempre es el header por lo que los valores se empiezan a almacenar en la 2.'
output_path = 'Inventory_clearance_report.xlsx'
writer = pd.ExcelWriter(output_path, engine='openpyxl')

for p_type in sorted (out_df['product_category'].unique()):
  temp = out_df[out_df['product_category'] == p_type].copy()

  temp.to_excel(writer, sheet_name= f'{p_type}', index=False)

  sheet = writer.book[f'{p_type}']

  for row_idx in range(2,len(temp)+2):

    decision = sheet[f"{chr(65 + temp.columns.get_loc('decision'))}{row_idx}"].value

    if decision == 'clearance':
      for col_idx in range(1,len(temp.columns)+1):
        sheet.cell(row = row_idx, column = col_idx).fill = fill_clear

    elif "discount" in decision:
      for col_idx in range(1,len(temp.columns)+1):
        sheet.cell(row = row_idx, column = col_idx).fill = fill_discount

writer.close()

# %% [markdown]
# ## Word summary report

# %%
'Nos aseguramos de tener una librería que pueda manipular word.'
# !pip install python-docx
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.0.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)

# %%
from docx import Document
from docx.shared import Inches
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# %%
'Creamos un tabla con la información necesaria para el resumen ejecutivo'
pivot = (
    pd.pivot_table(
        out_df,
        index='product_category',
        columns='decision',
        values='sku',
        aggfunc='count',
        fill_value=0
    )
    .reset_index()
)
pivot['discount'] = pivot['10% discount'] + pivot['20% discount'] + pivot['30% discount']

# %%
pivot.columns
# Out:
# Index(['product_category', '10% discount', '20% discount', '30% discount',
#        'clearance', 'ok', 'discount'],
#       dtype='object', name='decision')

# %%
pivot
# Out:
# decision product_category  10% discount  20% discount  30% discount  \
# 0                       A             0             4             0
# 1                       B            20             0             0
# 2                       C             0             0             0
# 3                       D             0             0             0
# 4                       E             8             0             0
# 5                       F            17             0             0
# 6                       G             0             0             1
# 7                       H            16             0             0
# 8                       I             5             0             0
# 9                       J             0             0             5
# 10                      K             0             0             0
# 11                      L             0             0             0
# 12                      M             0             0             0
# 13                      N             0             0            14
# 14                      O             0             6             0
# 15                      P             2             0             0
# 16                      Q             0             0             0
# 17                      R             0             0             0
# 18                      S             3             0             0
# 19                      T            10             0             0
# 20                      U             0             0             0
# 21                      V             0             0            13
# 22                      W             0             8             0
# 23                      X             0             0             5
# 24                      Y             0             0             0
# 25                      Z             0             0             0
#
# decision  clearance   ok  discount
# 0               221  549         4
# 1               194  541        20
# 2               210  569         0
# 3               220  521         0
# 4               219  552         8
# 5               218  559        17
# 6               200  547         1
# 7               192  564        16
# 8               219  500         5
# 9               226  592         5
# 10              212  570         0
# 11              203  577         0
# 12              222  552         0
# 13              211  516        14
# 14              215  573         6
# 15              179  551         2
# 16              208  559         0
# 17              231  541         0
# 18              195  549         3
# 19              209  548        10
# 20              217  559         0
# 21              192  609        13
# 22              220  541         8
# 23              202  549         5
# 24              214  551         0
# 25              224  551         0

# %%
pivot = pivot [['product_category', 'discount','clearance','ok']]

# %%
pivot
# Out:
# decision product_category  discount  clearance   ok
# 0                       A         4        221  549
# 1                       B        20        194  541
# 2                       C         0        210  569
# 3                       D         0        220  521
# 4                       E         8        219  552
# 5                       F        17        218  559
# 6                       G         1        200  547
# 7                       H        16        192  564
# 8                       I         5        219  500
# 9                       J         5        226  592
# 10                      K         0        212  570
# 11                      L         0        203  577
# 12                      M         0        222  552
# 13                      N        14        211  516
# 14                      O         6        215  573
# 15                      P         2        179  551
# 16                      Q         0        208  559
# 17                      R         0        231  541
# 18                      S         3        195  549
# 19                      T        10        209  548
# 20                      U         0        217  559
# 21                      V        13        192  609
# 22                      W         8        220  541
# 23                      X         5        202  549
# 24                      Y         0        214  551
# 25                      Z         0        224  551

# %%
'Lógica para la creación del archivo de texto.'
doc = Document()
logo_path = 'company_logo.png'

try:
  logo_paragraph = doc.add_paragraph()
  logo_run = logo_paragraph.add_run()
  logo_run.add_picture(logo_path, width=Inches(1.5))
  logo_paragraph.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
except Exception as e:
  print(f'Error adding logo:', e)

doc.add_heading("Inventory Clearance Summary Report", level=1)

total_clear = (out_df['decision'] == 'clearance').sum()
total_discount = total_discount = (out_df['decision'].str.contains('discount')).sum()

total_profit = out_df['final_profit'].sum()

executive_text= f"""
This report summarizes the inventory clearance recomendations for all product types.

A total of {total_clear} SKUs require clearance, indicating inmediate action is necessary to reduce holding costs. A total of {total_discount} can be sold at a discount to optimize profitability.

The remaining SKUs fall into discount or no-action categories, allowing a more strategic approach to inventory optimization. By following this strategy the company can get a total profit of its current inventory of $ {total_profit:,.0f}.
"""
for block in executive_text.strip().split("\n\n"):
    p= doc.add_paragraph(block)
    p.alignment = WD_PARAGRAPH_ALIGNMENT.JUSTIFY
doc.add_heading("SKU Decision Counts per Product Type", level = 2)

rows, cols = pivot.shape
table = doc.add_table(rows=rows+1, cols=cols)
table.style = "Light List"

for j, col_name in enumerate(pivot.columns):
    table.rows[0].cells[j].text =  str(col_name)
    table.rows[0].cells[j].paragraphs[0].alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
    for i in range(rows):
      for j in range(cols):
        table.rows[i+1].cells[j].text = str(pivot.iloc[i,j])
        table.rows[i+1].cells[j].paragraphs[0].alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
output_path = 'Inventory_clearance_summary.docx'
doc.save(output_path)

print("Word report created", output_path)
# Out:
# Word report created Inventory_clearance_summary.docx
